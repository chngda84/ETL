# %%
# Dependencies
import pandas as pd

from bs4 import BeautifulSoup
import requests
import pymongo

from sqlalchemy import create_engine
from config import username
from config import password

# %% [markdown]
# # Datasource 1

# %%
# CSV for 1)	Data source 1 – Alphabetical List of Western Australian Schools (XLSX)

# Store CSV into df
csv_file = "Resources/WASchoolsList_cleaned.csv"
WASchools_df = pd.read_csv(csv_file)
WASchools_df.head()
# Out:
#    Code                    School Name                    Street  \
# 0  5001       ADAM ROAD PRIMARY SCHOOL            HOTCHIN STREET
# 1  1463               AL-AMEEN COLLEGE         57 SOUTHGATE ROAD
# 2  1397      AL-HIDAYAH ISLAMIC SCHOOL  CNR HEDLEY ST/NYAMUP WAY
# 3  8001  ALBANY COMMUNITY KINDERGARTEN       136 SERPENTINE ROAD
# 4  5002          ALBANY PRIMARY SCHOOL            SUFFOLK STREET
#
#           Suburb State  Postcode             Postal Street  Postal Suburb  \
# 0  SOUTH BUNBURY    WA      6230            HOTCHIN STREET  SOUTH BUNBURY
# 1       LANGFORD    WA      6147         57 SOUTHGATE ROAD       LANGFORD
# 2        BENTLEY    WA      6102  CNR HEDLEY ST/NYAMUP WAY        BENTLEY
# 3         ALBANY    WA      6330               PO BOX 5670         ALBANY
# 4         ALBANY    WA      6330            SUFFOLK STREET         ALBANY
#
#   Postal State  Postal Postcode  ...   Y06  UPR   Y07   Y08   Y09   Y10   Y11  \
# 0           WA             6230  ...  45.0  NaN   NaN   NaN   NaN   NaN   NaN
# 1           WA             6147  ...  96.0  NaN  83.0  79.0  66.0  67.0  48.0
# 2           WA             6102  ...  24.0  NaN   NaN   NaN   NaN   NaN   NaN
# 3           WA             6332  ...   NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 4           WA             6330  ...  58.0  NaN   NaN   NaN   NaN   NaN   NaN
#
#     Y12  USE  Total Students
# 0   NaN  NaN             446
# 1  45.0  NaN           1,136
# 2   NaN  NaN             202
# 3   NaN  NaN              29
# 4   NaN  NaN             426
#
# [5 rows x 35 columns]

# %%
# look at all the columns available
WASchools_df.columns
# Out:
# Index(['Code', 'School Name', 'Street', 'Suburb', 'State', 'Postcode',
#        'Postal Street', 'Postal Suburb', 'Postal State', 'Postal Postcode',
#        'Latitude', 'Longitude', 'Phone', 'Education Region',
#        'Broad Classification', 'Classification Group', 'Low Year', 'High Year',
#        'KIN', 'PPR', 'Y01', 'Y02', 'Y03', 'Y04', 'Y05', 'Y06', 'UPR', 'Y07',
#        'Y08', 'Y09', 'Y10', 'Y11', 'Y12', 'USE', 'Total Students'],
#       dtype='object')

# %%
# create new data with only relevant columns
new_WASchools_df = WASchools_df[['School Name', 'Classification Group', 'Y12']].copy()
new_WASchools_df.head()
# Out:
#                      School Name     Classification Group   Y12
# 0       ADAM ROAD PRIMARY SCHOOL          PRIMARY SCHOOLS   NaN
# 1               AL-AMEEN COLLEGE           NON-GOVERNMENT  45.0
# 2      AL-HIDAYAH ISLAMIC SCHOOL           NON-GOVERNMENT   NaN
# 3  ALBANY COMMUNITY KINDERGARTEN  COMMUNITY KINDERGARTENS   NaN
# 4          ALBANY PRIMARY SCHOOL          PRIMARY SCHOOLS   NaN

# %%
# remove instances where Y12 is NaN - i.e. dataset is only for secondary schools with Y12 students in it
nan_value = float("NaN")
new_WASchools_df.replace("", nan_value, inplace=True)
new_WASchools_df.dropna(subset = ["Y12"], inplace=True)

# create id
new_WASchools_df.insert(0, 'School_ID', range(0, 0 + len(new_WASchools_df)))

# rename columns
new_WASchools_df = pd.DataFrame(new_WASchools_df).rename(columns = {'School Name':'School_Name'})
new_WASchools_df = pd.DataFrame(new_WASchools_df).rename(columns = {'Classification Group':'Classification_Group'})

new_WASchools_df.head()
# Out:
#     School_ID                                School_Name Classification_Group  \
# 1           0                           AL-AMEEN COLLEGE       NON-GOVERNMENT
# 5           1  ALBANY SECONDARY EDUCATION SUPPORT CENTRE    EDUCATION SUPPORT
# 6           2                  ALBANY SENIOR HIGH SCHOOL    SECONDARY SCHOOLS
# 8           3                    ALKIMOS BAPTIST COLLEGE       NON-GOVERNMENT
# 12          4                        ALL SAINTS' COLLEGE       NON-GOVERNMENT
#
#       Y12
# 1    45.0
# 5    17.0
# 6   130.0
# 8    12.0
# 12  144.0

# %%
# get unique classification groups
classification = new_WASchools_df["Classification_Group"].unique()
classification_df = pd.DataFrame(classification).rename(columns = {0:'Classification_Group'})
# create id
classification_df.insert(0, 'Classification_ID', range(0, 0 + len(classification_df)))
classification_df.head()
# Out:
#    Classification_ID   Classification_Group
# 0                  0         NON-GOVERNMENT
# 1                  1      EDUCATION SUPPORT
# 2                  2      SECONDARY SCHOOLS
# 3                  3           K-12 SCHOOLS
# 4                  4  DISTRICT HIGH SCHOOLS

# %%
#  Replace the Classification Group with the ID from the primary table
new_WASchools_df2 = pd.merge(new_WASchools_df, classification_df, on="Classification_Group", how="left").drop("Classification_Group", axis=1)
new_WASchools_df2
# Out:
#      School_ID                                School_Name    Y12  \
# 0            0                           AL-AMEEN COLLEGE   45.0
# 1            1  ALBANY SECONDARY EDUCATION SUPPORT CENTRE   17.0
# 2            2                  ALBANY SENIOR HIGH SCHOOL  130.0
# 3            3                    ALKIMOS BAPTIST COLLEGE   12.0
# 4            4                        ALL SAINTS' COLLEGE  144.0
# ..         ...                                        ...    ...
# 307        307                 WOODVALE SECONDARY COLLEGE  212.0
# 308        308               WYNDHAM DISTRICT HIGH SCHOOL    6.0
# 309        309                  YANCHEP SECONDARY COLLEGE   70.0
# 310        310             YIRAMALAY/WESLEY STUDIO SCHOOL   11.0
# 311        311             YOUTH FUTURES COMMUNITY SCHOOL  101.0
#
#      Classification_ID
# 0                    0
# 1                    1
# 2                    2
# 3                    0
# 4                    0
# ..                 ...
# 307                  2
# 308                  4
# 309                  2
# 310                  0
# 311                  0
#
# [312 rows x 4 columns]

# %%
new_WASchools_df2.loc[new_WASchools_df2['School_Name'] == "APPLECROSS SENIOR HIGH SCHOOL"]
# Out:
#    School_ID                    School_Name    Y12  Classification_ID
# 6          6  APPLECROSS SENIOR HIGH SCHOOL  286.0                  2

# %% [markdown]
# # Datasource 2

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.schools_db
collection = db.applecross

# %%
# URL of page to be scraped - Data source 1 – REIWA Applecross suburb profile, secondary schools
url = 'https://reiwa.com.au/suburb/applecross/'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.text, 'lxml')

print(soup)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]--><!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]--><!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en">
# <!--<![endif]-->
# <head><title>
# 	Applecross Suburb Profile | Property Market, House Prices and More - REIWA
# </title><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><meta content="Interested in buying, renting or investing in Applecross? View median house prices, growth rates, demographics, schools and more with our suburb profile." name="description"/><meta content="REIWA" name="author"/><link href="/WorkArea/FrameworkUI/css/ektron.stylesheet.ashx?id=-991207082+-409962787+-2046276955+-1495356069+490163735+-719310687+-384744968+-987815539+2007979625+-2081147131+-545874270+1317633679+-1252017282+-707468958+-2117417196+-1057278288+1510350268+-559785714+-243909663+168415565+153441047+-1734950019+976897492+-1759591071&amp;ver=3.21.0" media="all" rel="stylesheet" type="text/css"/><script src="/WorkArea/FrameworkUI/js/ektron.javascript.ashx?id=-569449246+-1939951303+-1080527330+-1687560804+-1388997516+2009761168+27274999+1979897163+-422906301+-1818005853+-991739241+-1251307564+-1916646153+-1357665627+-667355712+1722613948+-1793043690" type="text/javascript"></script><link href="/WorkArea/FrameworkUI/css/ektron.stylesheet.ashx?id=-300771134+1985268503" media="all" rel="stylesheet" type="text/css"/><link href="/ux/reiwa/ux/ico/favicon.png" rel="shortcut icon"/><meta content="be41fdeb43534fa1a5b477a75e31e01a" name="p:domain_verify"/>
# <!-- HTML5 shim and Respond.js IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
# 	<script src="/ux/reiwa/ux/js/vendor/html5shiv.js"></script>
# 	<script src="/ux/reiwa/ux/js/vendor/respond.min.js"></script>
# 	<![endif]-->
# <!-- Google Publisher Tag Service -->
# <script async="" type="text/javascript">
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     (function () {
#         var gads = document.createElement('script');
#         gads.async = true;
#         gads.type = 'text/javascript';
#         var useSSL = 'https:' == document.location.protocol;
#         gads.src = (useSSL ? 'https:' : 'http:') + '//www.googletagservices.com/tag/js/gpt.js';
#         var node = document.getElementsByTagName('script')[0];
#         node.parentNode.insertBefore(gads, node);
#     })();
# </script>
# <script async="" type="text/javascript">
#     googletag.cmd.push(function () {
#         googletag.pubads().setTargeting('Page_ID', '3030').setTargeting('suburb', "applecross").collapseEmptyDivs();
#     });
# </script>
# <script async="" type="text/javascript"> dataLayer = [{  }]; </script>
# <!-- /Google Publisher Tag Service -->
# <link href="https://reiwa.com.au/suburb/applecross/" rel="canonical"/>
# <!-- Snap-In Chat meta tag -->
# <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/><link as="font" crossorigin="" href="/ux/reiwa/ux/fonts/Gibson-Regular-webfont.woff" rel="preload" type="font/woff"/><link as="font" crossorigin="" href="/ux/reiwa/mobile/fonts/Gibson-Regular-webfont.woff" rel="preload" type="font/woff"/><link as="font" crossorigin="" href="/ux/reiwa/ux/fonts/Gibson-Light-webfont.woff" rel="preload" type="font/woff"/><link as="font" crossorigin="" href="/ux/reiwa/ux/fonts/Gibson-SemiBold-webfont.woff" rel="preload" type="font/woff"/><link as="font" crossorigin="" href="/ux/reiwa/ux/fonts/glyphicons-halflings-regular.woff" rel="preload" type="font/woff2"/><link as="font" crossorigin="" href="/ux/reiwa/ux/fonts/fontawesome-webfont.woff2?v=4.3.0" rel="preload" type="font/woff2"/><link as="script" href="https://securepubads.g.doubleclick.net/tag/js/gpt.js" rel="preload"/><link as="script" href="/UX/vendor/jQuery/jquery.min.js" rel="preload"/><link as="script" href="/ux/vendor/jquery/jquery.migrate.js" rel="preload"/><link href="https://www.googletagservices.com/" rel="preconnect"/>
# <script type="text/javascript">
#         console.log('main master - lazysizes loaded')
#     </script>
# <script type="text/javascript">
#         // Passive event listeners
#         jQuery.event.special.touchstart = {
#             setup: function (_, ns, handle) {
#                 this.addEventListener("touchstart", handle, { passive: !ns.includes("noPreventDefault") });
#             }
#         };
#         jQuery.event.special.touchmove = {
#             setup: function (_, ns, handle) {
#                 this.addEventListener("touchmove", handle, { passive: !ns.includes("noPreventDefault") });
#             }
#         };
#     </script>
# <meta content="https://reiwa.com.au/suburb/applecross/" property="og:url"/><meta content="https://reiwa.com.au/uploadedImages/Public/Content/Suburb_Profiles/Metro/Applecross.jpg" property="og:image"/><meta content="reiwa.com - Suburb profile for Applecross" property="og:title"/><meta content="REIWA" property="og:site_name"/><meta content="Applecross is an affluent riverside suburb of Perth bound by the Canning Highway and Swan River. Part of the City of Melville's municipality, Applecross is a predominantly residential area with commercial activity along Canning Highway.Life in Applecross Home to numerous parks and reserves, ..." property="og:description"/></head>
# <body>
# <form action="/suburb/applecross/" id="aspnetForm" method="post">
# <div class="aspNetHidden">
# <input id="EktronClientManager" name="EktronClientManager" type="hidden" value="-991207082,-409962787,-2046276955,-1495356069,490163735,-719310687,-384744968,-987815539,2007979625,-2081147131,-545874270,1317633679,-1252017282,-707468958,-2117417196,-1057278288,1510350268,-559785714,-243909663,168415565,153441047,1860464903,-1163639748,620270482,-1250874870,1699482349,-1251490955,67436383,-993784877,1349732761,757130540,1600218572,-1153875193,1914965633,1853295748,902309670,-919434566,-1293123525,-127140165,-847686342,2140596708,1581766698,695237143,-1574337509,969804857,-1734950019,976897492,-1152689727,-1085004766,-1716608124,998994086,-569449246,-1939951303,-1080527330,-1687560804,-1388997516,2009761168,27274999,1979897163,-422906301,-1818005853,-991739241,-1759591071,-1251307564,-1916646153,-1357665627,-2076844529,1792486806,-667355712,177711107,-535651174,509557905,1722613948,-1793043690,-300771134,1985268503"/>
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# </div>
# <script src="/ScriptResource.axd?d=NJmAwtEo3Ipnlaxl6CMhvt6JcV5otYwSDXRp1Fx0hkonI3YVFBtDNqYTKn8myeZAvwpguKQTdkt4dCsk2torxOnkX7q4oRDVySWA1GtgKZK0yxpfGtwHnPvCs75CeZBGM5EfO6yTGadrO_JUkvsVLd-IV4Q1&amp;t=ffffffffcc461371" type="text/javascript"></script>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="AD52D534"/>
# </div>
# <!--sse-->
# <div>
# <div class="page-container residential-container" id="ctl00_PageContainer">
# <style>
#     .impersonation-alert {
#         background-color: #A455AB;
#         border-color: #A455AB;
#         border-radius: 0;
#         margin-bottom: 0 !important;
#         padding: 2px;
#     }
# </style>
# <style>
#     .globalnav-login-button-member {
#         background: #fff;
#         color: #444;
#     }
#     .globalnav-login-button {
#         color: #fff;
#         background: #444;
#     }
# </style>
# <div class="row nav-other-container">
# <ul class="nav-mobile-footer hide-desktop" id="ulMobile">
# <li>
# <a href="/" title="reiwa.com">
# <span>reiwa.com</span>
# </a>
# <ul class="global-nav-sub">
# <li>
# <a href="/" title="For Sale">
# <span>For Sale</span>
# </a>
# </li>
# <li>
# <a href="/rent/" title="For Rent">
# <span>For Rent</span>
# </a>
# </li>
# <li>
# <a href="/sold/" title="Sold">
# <span>Sold</span>
# </a>
# </li>
# <li>
# <a href="/agent-finder/" title="AgentFinder">
# <span>AgentFinder</span>
# </a>
# </li>
# <li>
# <a href="/the-wa-market/" title="Research">
# <span>Research</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/commercial/" title="Commercial">
# <span>Commercial</span>
# </a>
# </li>
# <li>
# <a href="/business/" title="Business">
# <span>Business</span>
# </a>
# </li>
# <li>
# <a href="/agent-finder/" title="Agents">
# <span>Agents</span>
# </a>
# </li>
# <li>
# <a href="http://reiwatraining.com.au/" title="Training">
# <span>Training</span>
# </a>
# </li>
# <li>
# <a href="/about-us/news/" title="News">
# <span>News</span>
# </a>
# </li>
# <li>
# <a href="/about-us/contact-us/" title="Contact us">
# <span>Contact us</span>
# </a>
# </li>
# </ul>
# <a class="globalnav-login-text tcon-text btn btn-login btn-sml btn-addon globalnav-login-button hide-desktop" href="javascript:__doPostBack('ctl00$uxGlobalTopNav$buttonAgentLoginMobile','')" id="ctl00_uxGlobalTopNav_buttonAgentLoginMobile">Agent Login</a>
# <a class="globalnav-login-text tcon-text btn btn-login btn-sml btn-addon globalnav-login-button hide-desktop" href="javascript:__doPostBack('ctl00$uxGlobalTopNav$buttonLoginMobile','')" id="ctl00_uxGlobalTopNav_buttonLoginMobile">Login</a>
# </div>
# <div class="mobile-header-container clearfix hide-desktop">
# <button aria-label="toggle menu" class="tcon tcon-menu--xbutterfly nav-open btn-header" type="button">
# <span aria-hidden="true" class="tcon-menu__lines"></span>
# </button>
# <a class="logo" href="/" id="ctl00_uxGlobalTopNav_GlobalNavLogoLink" title="REIWA.com Leader in WA property data">
# <span class="sr-only">REIWA.com Leader in WA Property Data</span>
# </a>
# </div>
# <style>
#     .globalnav-linkitem {
#         margin-top: 30px;
#         display: inline-block;
#         margin-right: 10px;
#         font-family: GibsonLightBold, Arial, Helvetica, sans-serif;
#         font-size: 9pt;
#     }
#
#     .globalnav-link {
#         text-decoration: none;
#         color: #2f343d;
#     }
#
#     .globalnav-link:hover {
#         text-decoration: none;
#         color: #19a1db;
#     }
#
#     .globalnav-link-selected,
#     .globalnav-link-selected:hover {
#         text-decoration: none;
#         color: #19a1db;
#     }
#
#     @media (min-width: 992px) {
#         .globalnav-linkitem {
#             font-size: 10pt;
#             margin-right: 20px;
#         }
#     }
#
#     .globalnav-shoppingcart-container {
#         font-size: 16pt;
#         text-decoration: none;
#         margin-top: 25px;
#     }
#
#         .globalnav-shoppingcart-container:hover {
#             text-decoration: none;
#         }
#
#     .globalnav-shoppingcart-itemcount {
#         font-size: 8pt;
#         font-family: GibsonLightLight, Arial, Helvetica, sans-serif;
#         border-radius: 50%;
#         width: 20px;
#         height: 20px;
#         background: #2f343d;
#         border: 2px solid #2f343d;
#         color: #fff;
#         text-align: center;
#         padding: 2px 4px 2px 4px;
#         position: relative;
#         left: -12px;
#         top: -12px;
#     }
#
#     .globalnav-shoppingcart-icon {
#         color: #19a1db;
#     }
#
#     .globalnav-login-button {
#         border-radius: 5px;
#         border-radius: 5px;
#         padding: 0 10px;
#     }
#
#     .btn-admin-login {
#         line-height: 24px !important;
#     }
#
#     .btn-login-primary {
#         font-weight: 400;
#     }
#
#     .globalnav-login-text {
#         font-size: 10pt;
#         font-family: GibsonLightBold, Arial, Helvetica, sans-serif;
#     }
#
#     .home-cta-icon {
#         vertical-align: top;
#         color: #fff;
#         font-size: 34pt;
#         height: 50px;
#         padding-left: 20px;
#     }
#
#     .home-cta-text {
#         font-family: GibsonLightRegular,Arial,Helvetica,sans-serif;
#         font-size: 16px;
#         color: #fff;
#     }
#
#     .home-cta-header {
#         font-family: GibsonLightRegular,Arial,Helvetica,sans-serif;
#         font-size: 26px;
#         color: #fff;
#     }
#
#     .home-cta-link {
#         width: 220px;
#         height: 50px;
#         font-family: GibsonLightRegular,Arial,Helvetica,sans-serif;
#         font-size: 16px;
#         color: #fff;
#         max-width: 100%;
#     }
#
#     /*.home-cta-link {
#         font-family: GibsonLightRegular,Arial,Helvetica,sans-serif;
#         font-size: 12pt;
#         background: #19a1db;
#         color: #fff !important;
#         border: 2px solid #fff;
#         padding-top: 12px;
#         padding-left: 15px;
#         width: 220px;
#         margin-top: 7px;
#         transition: background-color 0.5s ease, border-color 0.5s ease;
#         text-decoration: none;
#     }
#
#     .home-cta-link:hover {
#         background: #0a6389;
#         text-decoration: none;
#         border: 2px solid #fff;
#     }*/
#
#     .home-cta-link {
#         font-family: GibsonLightRegular,Arial,Helvetica,sans-serif;
#         font-size: 16px;
#         background: #19a1db;
#         color: #fff !important;
#         border: 2px solid #fff;
#         padding-top: 12px;
#         padding-left: 15px;
#         width: 220px;
#         margin-top: 7px;
#         transition: background-color 0.5s ease, border-color 0.5s ease;
#         text-decoration: none;
#     }
#
#     .home-cta-link:hover {
#         background: #0a6389;
#         text-decoration: none;
#         border: 2px solid #fff;
#     }
#
#     .header-reiwa-com-link {
#         height: 52px;
#         font-size: 16px;
#         font-family: GibsonLightBold,Arial,Helvetica,sans-serif;
#         padding: 12px 20px 0 20px;
#         color: #19a1db;
#         text-decoration: none;
#     }
#
#     .header-reiwa-com-link:hover {
#         color: #0A6389;
#         text-decoration: none;
#     }
#
#     .header-adbar {
#
#     }
# </style>
# <!-- Public site header (Header) -->
# <header class="header">
# <div class="clearfix">
# <div class="container">
# <div class="row vert-rhythm-lg hidden-xs">
# <div class="col-sm-3 col-md-3 col-lg-3">
# <a class="logo" href="/" title="Buy Rent &amp; Sell Property &amp; Real Estate in Perth WA"></a>
# </div>
# <div class="col-sm-6 col-md-6 col-lg-6 text-center">
# <div class="globalnav-linkitem">
# <a class="globalnav-link globalnav-link-selected" href="/">reiwa.com</a>
# </div>
# <div class="globalnav-linkitem">
# <a class="globalnav-link" href="/commercial/">Commercial</a>
# </div>
# <div class="globalnav-linkitem">
# <a class="globalnav-link" href="/business/">Business</a>
# </div>
# <div class="globalnav-linkitem">
# <a class="globalnav-link" href="/agent-finder/">Agents</a>
# </div>
# <div class="globalnav-linkitem remove-margin">
# <a class="globalnav-link" href="http://reiwatraining.com.au/">Training</a>
# </div>
# </div>
# <div class="col-sm-3 col-md-3 col-lg-3">
# <div class="inline-block pull-right vert-top-xxl">
# <!-- Login control (Login) -->
# <style type="text/css">
#   .form-login .form-input-inline.inline-checkbox {
#     width: 150px;
#   }
#   .form-login .inline-checkbox label {
#     display: inline;
#   }
# </style>
# <script type="text/ecmascript">
#   $(function () {
#     InitLoginButton('ctl00_uxHeader_uxLogin_hfActiveMenu', 'ctl00_uxHeader_uxLogin_hfCallbackButton', 'dropdown-anonymous');
#   });
#
#   function SelectedBranch() {
#     var checkbox = $('.agency-branch fieldset .radio .checked').find('.custom-chk');
#     $('#ctl00_uxHeader_uxLogin_hfAgencyBranch').val(checkbox.attr('AgencyNo') + ";" + checkbox.attr('BranchNo'));
#     return true;
#   }
# </script>
# <div class="dropdown site-login" id="ctl00_uxHeader_uxLogin_uxLoginWrapper">
# <a class="btn btn-sml btn-addon globalnav-login-button btn-login-agent btn-login btn-login" href="https://members.reiwa.com.au/" id="ctl00_uxHeader_uxLogin_uxAgentAdminLoginLink"><span class="globalnav-login-text btn-admin-login hidden-sm">Member Site</span><span class="globalnav-login-text btn-admin-login hidden-md hidden-lg">Admin</span></a>
# <a class="btn-primary btn btn-sml btn-addon btn-rnd" href="/My-Account" id="ctl00_uxHeader_uxLogin_uxLoginLink"><span class="globalnav-login-text btn-login-primary">Login</span></a>
# <!-- Login DropList -->
# <div class="dropdown-wrapper">
# <div class="dropdown-anonymous dropdown-menu dropdown-primary pull-right">
# <div class="form-login" id="ctl00_uxHeader_uxLogin_uxLoginPanel" role="form">
# <div class="login-message" id="ctl00_uxHeader_uxLogin_uxLoginMessage"></div>
# <div class="forgot-password">
# <a href="/My-Account/Forgot-Password/">Forgotten your password?</a>
# </div>
# <div>
# <span class="pull-left">Don't have a login?<br/>
# <a href="/My-Account/?reg=1">Register now</a>
# </span>
# <input class="form-control website-user-comment" id="ctl00_uxHeader_uxLogin_uxWebsiteUserComment" name="ctl00$uxHeader$uxLogin$uxWebsiteUserComment" placeholder="Required" type="text"/>
# <a class="btn btn-primary btn-sml btn-input pull-right" href='javascript:WebForm_DoPostBackWithOptions(new WebForm_PostBackOptions("ctl00$uxHeader$uxLogin$uxLogin", "", true, "", "", false, true))' id="ctl00_uxHeader_uxLogin_uxLogin">Login</a>
# </div>
# </div>
# </div>
# <!-- Register -->
# <div class="dropdown-register dropdown-menu dropdown-primary pull-right">
# </div>
# <!-- styles once logged in as Non-Members -->
# <!-- styles once logged in as Members -->
# <input id="ctl00_uxHeader_uxLogin_hfActiveMenu" name="ctl00$uxHeader$uxLogin$hfActiveMenu" type="hidden" value="dropdown-anonymous"/>
# <input id="ctl00_uxHeader_uxLogin_hfCallbackButton" name="ctl00$uxHeader$uxLogin$hfCallbackButton" type="hidden"/>
# </div>
# <!-- /Login DropList -->
# </div>
# <!-- /Login control (Login) -->
# </div>
# <a class="globalnav-shoppingcart-container inline-block pull-right" href='javascript:WebForm_DoPostBackWithOptions(new WebForm_PostBackOptions("ctl00$uxHeader$uxShoppingCart", "", true, "", "", false, true))' id="ctl00_uxHeader_uxShoppingCart">
# <span class="fa fa-shopping-cart globalnav-shoppingcart-icon"></span>
# <span class="globalnav-shoppingcart-itemcount">0</span>
# </a>
# </div>
# </div>
# <div class="row vert-rhythm hidden-xs">
# <div class="col-sm-1 col-md-1 col-lg-1">
# </div>
# <div class="col-sm-10 col-md-10 col-lg-10" style="padding-right: 40px;">
# <!-- Leaderboard Header 728x90 -->
# <!-- Ad script external (AdExternal) -->
# <!-- Content Info (122965, REIWA_ROS__728x90_POS1) -->
# <!-- AdItem #1 -->
# <div class="pull-right ad ad-lb hidden-xs hidden-sm" id="div-gpt-ad-122965-0-f5b77cb12a5e49dab48c0b2076d83536">
# <script>
#    googletag.cmd.push(function () {
#        googletag.defineSlot('/27776805/REIWA_ROS__728x90_POS1', [728, 90], 'div-gpt-ad-122965-0-f5b77cb12a5e49dab48c0b2076d83536').addService(googletag.pubads());
#        googletag.enableServices();
#        googletag.display('div-gpt-ad-122965-0-f5b77cb12a5e49dab48c0b2076d83536');
#    });
# </script>
# </div>
# <!-- /AdItem #1 -->
# <!-- /Ad script external (AdExternal) -->
# <!-- /Leaderboard Header 728x90 -->
# </div>
# <div class="col-sm-1 col-md-1 col-lg-1">
# </div>
# </div>
# </div>
# <div class="header-adbar hide-desktop" header="" leaderboard="" style="margin: 15px auto !important;">
# <!-- Ad script external (AdExternal) -->
# <!-- Content Info (113816633349, REIWA_MOBILE_GLOBAL_300X50_HEADER) -->
# <!-- AdItem #1 -->
# <div class="center-block ad" id="div-gpt-ad-113816633349-0-b0516fe2010c4374946a75b2c327177c">
# <script>
#    googletag.cmd.push(function () {
#        googletag.defineSlot('/27776805/REIWA_MOBILE_GLOBAL_300X50_HEADER', [320, 50], 'div-gpt-ad-113816633349-0-b0516fe2010c4374946a75b2c327177c').addService(googletag.pubads());
#        googletag.enableServices();
#        googletag.display('div-gpt-ad-113816633349-0-b0516fe2010c4374946a75b2c327177c');
#    });
# </script>
# </div>
# <!-- /AdItem #1 -->
# <!-- /Ad script external (AdExternal) -->
# <!-- /Leaderboard Header 300x90 -->
# </div>
# </div>
# </header>
# <!-- /Public site header (Header) -->
# <span id="ctl00_uxTopFormPlaceholder"><script type="text/javascript">var SolrUrl = 'https://reiwa.com.au/solr/b9e47b68/'; var imageServerUrl = 'https://imagecdn.reiwa.com.au/';</script></span>
# <script type="text/javascript">
#         Ektron.PBSettings = { 'dontClose': false }
#     </script>
# <div class="ektron-ux-UITheme ux-app-siteApppageBuilder-setSizeTemplate">
# </div>
# <script id="EktronScriptBlockjahis" type="text/javascript">
#
# Ektron.ready(function(event, eventName){
#
#                 $ektron(".ux-app-siteApppageBuilder-setSizeTemplate .ui-dialog-buttonpane a").button();
#                 $ektron(".ux-app-siteApppageBuilder-setSizeTemplate .framework").accordion({
#                     heightStyle: "content",
#                     activate: function(event, ui){
#                         $ektron(ui).closest(".ui-accordion").accordion("refresh");
#                     }
#                 });
#                 $ektron(".ux-app-siteApppageBuilder-setSizeTemplate").draggable({ handle: "div.ui-dialog-titlebar ", containment: $ektron("body") });
#
# });
#
#
# </script>
# <!-- Header container -->
# <div class="container">
# <!--Navigation and search drop downs -->
# <style>
#     .alert66248556be064c0a83220cfa7f5503c8-position {
#         position: absolute;
#         padding: 10px 10px 10px 10px;
#         background-color: #fff;
#         color: #333;
#         border: 1px solid #999;
#         display: none;
#
#         z-index: 99999;
#         left: 50%;
#         top: 52px;
#
#         margin-left: -175px;
#
#         width: 350px;
#     }
# </style>
# <div style="position:relative; left: 0px; top: 0px;">
# <div class="alert66248556be064c0a83220cfa7f5503c8-position" id="alert66248556be064c0a83220cfa7f5503c8">
# <span class="pull-right glyphicon glyphicon-remove" id="alert66248556be064c0a83220cfa7f5503c8-close-button"></span><br/>
# </div>
# </div>
# <!-- Validation Modal -->
# <div aria-hidden="true" class="modal fade" id="search-limit-alert-container" role="dialog" tabindex="-1">
# <div class="modal-dialog" style="width:600px">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button"><span class="glyphicon glyphicon-remove"></span></button>
# <strong class="modal-title lead">Too many search terms</strong>
# </div>
# <div class="modal-body clearfix">
# <p>Your search has been limited to the first 30 items entered. </p>
# <span class="pull-right modal-buttons">
# <button class="btn btn-secondary btn-sml horz-rhythm-lg" data-dismiss="modal" type="button">OK</button>
# </span>
# </div>
# </div>
# </div>
# </div>
# <!-- /Validation Modal -->
# </div>
# <!-- Content -->
# <div class="container">
# <div class="row">
# <div class="col-xs-8 col-md-9 twoColumnLeft">
# <!-- Page Breadcrumbs (Breadcrumbs) -->
# <ol class="breadcrumb vert-rhythm-md" id="ctl00_uxContentHolder_uxBreadcrumbs_uxListViewBreadcrumb_uxBreadcrumbs">
# <li>
# <a href="/" title="">
#         Home
#       </a>
# </li>
# <li>
# <a href="/The-WA-Market/" title="">
#         The WA Market
#       </a>
# </li>
# <li>
# <a href="/The-WA-Market/Suburb-Profiles-Search/" title="">
#         Suburb profile
#       </a>
# </li>
# <li class="active">
#       Applecross
#     </li>
# </ol>
# <!-- Page Breadcrumbs (Breadcrumbs) -->
# </div>
# <div class="col-xs-8 col-md-9 twoColumnLeft">
# <!-- Adjustable top dropzone -->
# <div class="" id="ctl00_uxContentHolder_dzMainTop_uxUpdatePanel">
# <div data-ux-pagebuilder="DropZone" id="ctl00_uxContentHolder_dzMainTop_uxDropZone">
# <div data-ux-pagebuilder="Column">
# <ul role="presentation">
# <li role="presentation">
# <div id="ctl00_uxContentHolder_dzMainTop_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxUpdatePanel">
# <div data-ux-pagebuilder="Widget">
# <div class="widgetBody">
# <!-- Suburb Profile Detail Page (SuburbProfileOverview) -->
# <div class="clearfix">
# <h1 class="pull-left col-xs-12 col-md-7">
#         Applecross
#         </h1>
# <div class="form-inline pull-right-md vert-rhythm-md pull-left-xs" role="form">
# <div id="ctl00_uxContentHolder_dzMainTop_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_SuburbProfileOverview_uxSuburbProfileSearchForm">
# <div class="form-group horz-rhythm col-xs-8">
# <label class="sr-only" for="find-suburb">Find another suburb</label>
# <style>
#     @media only screen and (max-width: 767px) {
#             .mobile-suburb-tb {
#                 width: 100%;
#             }
#         }
# </style>
# <input class="txt-suburb-search-autocomplete form-control clearable mobile-suburb-tb" id="txtSuburbSearch" name="ctl00$uxContentHolder$dzMainTop$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$SuburbProfileOverview$SuburbsAutoComplete$txtSuburbSearch" placeholder="Search other profiles" type="text"/>
# <script type="text/javascript">
#     var prm = Sys.WebForms.PageRequestManager.getInstance();
#     prm.add_endRequest(function() {
#         BindSuburbAutoComplete();
#     });
#
#     $(document).ready(function() {
#         BindSuburbAutoComplete();
#     });
#
#     function BindSuburbAutoComplete() {
#         var targetListControl = $("#txtSuburbSearch");
#             configureAutoComplete(targetListControl,
#                 'https://ac.reiwa.com.au/api/Geography',
#                 10,
#                 false);
#
#         window.reiwaCommon.geographyServiceUrl = 'https://ac.reiwa.com.au/api/Geography';
#     }
# </script>
# </div>
# <a class="btn btn-primary btn-addon" href='javascript:WebForm_DoPostBackWithOptions(new WebForm_PostBackOptions("ctl00$uxContentHolder$dzMainTop$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$SuburbProfileOverview$btnSuburbSearch", "", true, "", "", false, true))' id="ctl00_uxContentHolder_dzMainTop_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_SuburbProfileOverview_btnSuburbSearch">
# <span class="glyphicon glyphicon-chevron-right"></span>
# </a>
# </div>
# </div>
# <div class="" style="clear: both;">
# <ul class="suburb-profiles-growth pull-left-xs pull-right-md">
# <li>
# <div class="suburb-profile-stats-mobile">
# <span class="glyphicon glyphicon-chevron-up success"></span>
# <span><strong>11.9%</strong></span>
# <span><small>ANNUAL<br/>GROWTH</small></span>
# </div>
# </li>
# <li>
# <div class="suburb-profile-stats-mobile">
# <span class="glyphicon glyphicon-chevron-up success"></span>
# <span><strong>$1,745,000</strong></span>
# <span><small>ANNUAL<br/>MED.PRICE</small></span>
# </div>
# </li>
# <li>
# <div class="suburb-profile-stats-mobile">
# <span class="glyphicon glyphicon-chevron-up success"></span>
# <span><strong>6,887</strong></span>
# <span><small>POPULATION</small></span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="module">
# <div class="module-content">
# <div class="row">
# <div class="col-xs-12 col-md-6">
# <p>Applecross is an affluent riverside suburb of Perth bound by the Canning Highway and Swan River. Part of the City of Melville's municipality, Applecross is a predominantly residential area with commercial activity along Canning Highway.</p><h2>Life in Applecross </h2><p>Home to numerous parks and reserves, Applecross is in the enviable position of being close to urban environments while still retaining its suburban charm. Some major features are the South of Perth Yacht Club, the Raffles Hotel, Restaurant and Lounge Bar and the Canning Highway commercial area, which provides residents with numerous restaurants and...
#           <a href="javascript:__doPostBack('ctl00$uxContentHolder$dzMainTop$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$SuburbProfileOverview$ReadMoreButton','')" id="ctl00_uxContentHolder_dzMainTop_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_SuburbProfileOverview_ReadMoreButton">read more</a>
# </p></div>
# <div class="col-xs-12 col-md-6">
# <div class="interactive-map">
# <img alt="Interactive Map" id="ctl00_uxContentHolder_dzMainTop_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_SuburbProfileOverview_uxMap" src="https://maps.googleapis.com/maps/api/staticmap?client=gme-reiwa&amp;center=Applecross,WA+Australia&amp;zoom=13&amp;size=350x350&amp;sensor=false&amp;signature=s424klhl7a7PSeGm9bb6C1W2zb0=&amp;channel=suburbProfile"/>
# </div>
# </div>
# </div>
# <div class="clearfix vert-rhythm-lg">
# <div class="pull-right-sm vert-bottom">
# <a class="btn btn-primary" href="https://maps.reiwa.com.au/#/marketView?location=-32.01931300,115.83443080&amp;zoom=15" id="ctl00_uxContentHolder_dzMainTop_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_SuburbProfileOverview_InteractiveMapLink" target="_blank">Explore suburb</a>
# </div>
# <div class="pull-left">
# <!-- Share buttons (ShareLink) -->
# <a class="share-facebook btn btn-primary" data-url="" href="#" style="min-width:40px;" title="Share on Facebook">
# <span class="icon social-icon-sm icon-fb-sm"></span><span class="sr-only">Share on Facebook</span></a>
# <a class="share-twitter btn btn-primary" data-twitter-text="View this suburb profile on reiwa.com:" data-url="" href="#" style="min-width:40px;" title="Tweet about this">
# <span class="icon social-icon-sm icon-twitter-sm"></span><span class="sr-only">Tweet about this</span></a>
# <a class="btn btn-primary" href="/cdn-cgi/l/email-protection#..." style="min-width:40px;" title="Email to a friend">
# <span class="glyphicon glyphicon-envelope"></span><span class="hidden-sm hidden-xs pull-right-md horz-left">Email to a friend</span>
# </a>
# <!-- /Share buttons (ShareLink) -->
# <a class="btn btn-primary" href="/Modals/Public/SuburbProfileBrochure.aspx?suburb_name=applecross" target="_blank"><span class="glyphicon glyphicon-print"></span><span class="hidden-sm hidden-xs horz-left pull-right-md">Print</span></a>
# </div>
# </div>
# </div>
# </div>
# <!-- Add modal dialogs for Save & Alert on Property to the page (SaveAndAlertModalForProperty) -->
# <!-- Modal Form (Show all the time if the user is unauthenticated) -->
# <div aria-hidden="true" class="modal fade" id="ux-unauthen-saveproperty-modal" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content modal-login-alert">
# <div class="modal-header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button"><span class="glyphicon glyphicon-remove"></span></button>
# <span class="modal-title pd-text-darkgrey pd-heading-small">Save property</span>
# </div>
# <div class="modal-body clearfix">
# <div class="vert-rhythm-bot-lg alert alert-warning">
#                 Login to save this property
#             </div>
# <div class="vert-rhythm-xl">
#                 To manage saved properties and alerts from any device, please <a id="hlSavePropertyPublicLogin">login</a> or <a href="/my-account/?reg=1" id="ctl00_uxContentHolder_dzMainTop_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_SuburbProfileOverview_ctl00_hlSavePropertyRegister">register</a> now.
#             </div>
# <div class="pull-right">
# <button class="btn btn-primary savesearch-button" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- Modal Form -->
# <!-- Modal Form (Only show to authenticated user once per session) -->
# <div aria-hidden="true" class="modal fade" id="ux-authen-saveproperty-modal" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content modal-login-alert">
# <div class="modal-header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button"><span class="glyphicon glyphicon-remove"></span></button>
# <span class="modal-title pd-text-darkgrey pd-heading-small">Save property</span>
# </div>
# <div class="modal-body clearfix">
# <div class="vert-rhythm-bot-lg alert alert-danger" id="divSavePropertyError" style="display: none"> </div>
# <div class="vert-rhythm-bot-lg alert alert-success">
#                 This property has been saved
#             </div>
# <div class="vert-rhythm vert-rhythm-lg">
# <p>We will send you immediate alerts for price changes and other updates to this property. You can manage frequency of these alerts from your <a href="/my-account/saved-properties/">Saved properties</a> page.</p>
# </div>
# <div class="pull-right">
# <button class="btn btn-primary savesearch-button" data-dismiss="modal" type="button">Close</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- Modal Form -->
# <!-- /Add modal dialogs for Save & Alert on Property to the page (SaveAndAlertModalForProperty) -->
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script type="text/javascript">
#     $(document).ready(function () {
#
#         $('#ux-unauthen-saveproperty-modal, #ux-authen-saveproperty-modal').on('hidden.bs.modal', function () {
#             CleanUpSavePropertyUrl();
#         });
#
#         $('#ux-unauthen-saveproperty-modal, #ux-authen-saveproperty-modal').on('shown.bs.modal', function () {
#             //sets the return url
#             var returnUrl = window.location.pathname + window.location.search;
#             $('#hlSavePropertyPublicLogin').attr('href', '/my-account/?ReturnUrl=' + returnUrl);
#             $('#hlSavePropertyMemberLogin').attr('href', '/members/login/?ReturnUrl=' + returnUrl);
#         });
#
#         CheckSavePropertyUrl();
#     });
#
#     function CheckSavePropertyUrl() {
#         var listingNo = getParameterByName('saveproperty');
#
#         if (listingNo != null && listingNo != '' && listingNo != 'undefined') {
#
#         }
#     }
# </script>
# <div aria-hidden="true" class="modal" id="common_error_messages" role="dialog" tabindex="-2">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header clearfix">
# <h2 class="pull-left">Error</h2>
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button"><span class="glyphicon glyphicon-remove"></span></button>
# </div>
# <div class="modal-body clearfix">
# <p>The following error occurred:</p>
# <ul class="error-list" id="message_list">
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- Suburb Profile Detail Page (SuburbProfileOverview) -->
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!-- Adjustable mid dropzone -->
# <div class="" id="ctl00_uxContentHolder_dzMainMid_uxUpdatePanel">
# <div data-ux-pagebuilder="DropZone" id="ctl00_uxContentHolder_dzMainMid_uxDropZone">
# <div data-ux-pagebuilder="Column">
# <ul role="presentation">
# <li role="presentation">
# <div id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxUpdatePanel">
# <div data-ux-pagebuilder="Widget">
# <div class="widgetBody">
# <style>
#     .suburb-chart-container {
#         width: 100%;
#     }
# </style>
# <script type="text/javascript">
#     function postgraph(value) {
#
#         var GrowthRatesVisibleForHouse = $("#ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_GrowthRatesVisibleForHouse");
#         var GrowthRatesVisibleForMultiRes = $("#ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_GrowthRatesVisibleForMultiRes");
#         var GrowthRatesVisibleForLand = $("#ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_GrowthRatesVisibleForLand");
#
#         var GrowthRatePanelForHouse = $("#GrowthRatePanelForHouse");
#         var GrowthRatePanelForMultiRes = $("#GrowthRatePanelForMultiRes");
#         var GrowthRatePanelForLand = $("#GrowthRatePanelForLand");
#
#         if (GrowthRatesVisibleForHouse.val() == "1" && value == "1") {
#             if (GrowthRatePanelForHouse) {
#                 GrowthRatePanelForHouse.show();
#             }
#
#             if (GrowthRatePanelForMultiRes) {
#                 GrowthRatePanelForMultiRes.hide();
#             }
#
#             if (GrowthRatePanelForLand) {
#                 GrowthRatePanelForLand.hide();
#             }
#         }
#         else if (GrowthRatesVisibleForMultiRes.val() == "1" && value == "2") {
#             if (GrowthRatePanelForHouse) {
#                 GrowthRatePanelForHouse.hide();
#             }
#
#             if (GrowthRatePanelForMultiRes) {
#                 GrowthRatePanelForMultiRes.show();
#             }
#
#             if (GrowthRatePanelForLand) {
#                 GrowthRatePanelForLand.hide();
#             }
#         }
#         else if (GrowthRatesVisibleForLand.val() == "1" && value == "3") {
#             if (GrowthRatePanelForHouse) {
#                 GrowthRatePanelForHouse.hide();
#             }
#
#             if (GrowthRatePanelForMultiRes) {
#                 GrowthRatePanelForMultiRes.hide();
#             }
#
#             if (GrowthRatePanelForLand) {
#                 GrowthRatePanelForLand.show();
#             }
#         }
#         else {
#             if (GrowthRatePanelForHouse) {
#                 GrowthRatePanelForHouse.hide();
#             }
#
#             if (GrowthRatePanelForMultiRes) {
#                 GrowthRatePanelForMultiRes.hide();
#             }
#
#             if (GrowthRatePanelForLand) {
#                 GrowthRatePanelForLand.hide();
#             }
#         }
#     }
#
#     $(document).ready(function() {
#         BindHandlers();
#
#
#     });
#
#     Sys.WebForms.PageRequestManager.getInstance().add_endRequest(function () {
#         BindHandlers();
#     });
#
#     // rebind events after updatepanel triggers
#     //var prm = Sys.WebForms.PageRequestManager.getInstance();
#     //prm.add_endRequest(function () {
#     //    BindHandlers();
#     //});
#
#     function BindHandlers() {
#
#         SuburbProfileAgeChart('AgeGraphContainer', "Residents under 18,Residents 19-24,Residents 25-34,Residents 35-49,Residents 50+", 'Aged 0 - 18,Aged 19 - 24,Aged 25 - 34,Aged 35 - 49,Aged 50+', "Applecross by Age", $("#ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_AgeYAxisData").val());
#
#         SuburbProfileHouseHoldsChart('HouseHoldsGraphContainer', '', "Couples without children,Couple family with children,Single parent family,Other families,Lone person,Group household", '', $('#ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_HouseHoldsYAxisData').val());
#
#         SuburbProfileOwnershipChart('OwnershipGraphContainer', '', "Other tenure type,Fully owned,Being purchased,Being rented", '', $('#ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_OwnershipYAxisData').val(), 280, null, 12);
#
#         SuburbProfilePropertyTypesChart('PropertyTypesGraphContainer', '', "House,Duplex/villa/town house,Flat/unit/apartment,Other dwelling", '', $('#ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_PropertyTypesYAxisData').val(), 280, null, 12);
#
#
#         DisplayCharts();
#     }
#
#     function DisplayCharts() {
#         var houseDisplay = $("#ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_HiddenMedianHousePriceDisplay");
#         var unitDisplay = $("#ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_HiddenMedianUnitPriceDisplay");
#         var landDisplay = $("#ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_HiddenMedianLandPriceDisplay");
#
#         var chartType = '';
#
#         if (houseDisplay && houseDisplay.length == 1) {
#             HideChart(houseDisplay, "MedianHouseTab", "house-price");
#
#             if (houseDisplay.val() != "False" && chartType == '') {
#                 chartType = '1';
#             }
#         }
#
#         if (unitDisplay && unitDisplay.length == 1) {
#             HideChart(unitDisplay, "MedianUnitTab", "multires-price");
#
#             if (unitDisplay.val() != "False" && chartType == '') {
#                 chartType = '2';
#             }
#         }
#
#         if (landDisplay && landDisplay.length == 1) {
#             HideChart(landDisplay, "MedianLandTab", "land-price");
#
#             if (landDisplay.val() != "False" && chartType == '') {
#                 chartType = '3';
#             }
#         }
#
#         if (chartType != '') {
#             postgraph(chartType);
#         }
#
#
#
#
#
#         if (houseDisplay.val() != "False") {
#             try { $('#MedianHouseTab').find('a')[0].click(); } catch(ex) { /* catch error, click() not supported on android browser */ };
#             $('#MedianHouseTab').addClass('active');
#         } else if (unitDisplay.val() != "False"){
#             try { $('#MedianUnitTab').find('a')[0].click(); } catch(ex) { /* catch error, click() not supported on android browser */ };
#             $('#MedianUnitTab').addClass('active');
#         } else if (landDisplay.val() != "False") {
#             try { $('#MedianLandTab').find('a')[0].click(); } catch(ex) { /* catch error, click() not supported on android browser */ };
#             $('#MedianLandTab').addClass('active');
#         }
#
#
#
#
#         $("#ChartPanel").removeClass("hidden");
#         $("#ChartPanelMessage").hide();
#
#     }
#
#     function HideChart(hiddenControl, tabName, chartDivName, chartType) {
#         // hide the tab and the chart
#         if (hiddenControl.val() == "False") {
#             $("#" + tabName).hide();
#             $("#" + chartDivName).hide();
#         }
#     }
#
# </script>
# <input id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_AgeXAxisData" name="ctl00$uxContentHolder$dzMainMid$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$ctl00$AgeXAxisData" type="hidden" value="Residents under 18,Residents 19-24,Residents 25-34,Residents 35-49,Residents 50+"/>
# <input id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_AgeXAxisDataLegend" name="ctl00$uxContentHolder$dzMainMid$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$ctl00$AgeXAxisDataLegend" type="hidden" value="Aged 0 - 18,Aged 19 - 24,Aged 25 - 34,Aged 35 - 49,Aged 50+"/>
# <input id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_AgeYAxisData" name="ctl00$uxContentHolder$dzMainMid$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$ctl00$AgeYAxisData" type="hidden" value="24.4,8.3,15.6,23.6,28.1"/>
# <input id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_HouseHoldsXAxisData" name="ctl00$uxContentHolder$dzMainMid$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$ctl00$HouseHoldsXAxisData" type="hidden" value="Couples without children,Couple family with children,Single parent family,Other families,Lone person,Group household"/>
# <input id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_HouseHoldsYAxisData" name="ctl00$uxContentHolder$dzMainMid$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$ctl00$HouseHoldsYAxisData" type="hidden" value="48,31.2,5.3,1.9,12.1,1.5"/>
# <input id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_PropertyTypesXAxisData" name="ctl00$uxContentHolder$dzMainMid$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$ctl00$PropertyTypesXAxisData" type="hidden" value="House,Duplex/villa/town house,Flat/unit/apartment,Other dwelling"/>
# <input id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_PropertyTypesYAxisData" name="ctl00$uxContentHolder$dzMainMid$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$ctl00$PropertyTypesYAxisData" type="hidden" value="63.1,24.8,12.1,0"/>
# <input id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_OwnershipXAxisData" name="ctl00$uxContentHolder$dzMainMid$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$ctl00$OwnershipXAxisData" type="hidden" value="Other tenure type,Fully owned,Being purchased,Being rented"/>
# <input id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_OwnershipYAxisData" name="ctl00$uxContentHolder$dzMainMid$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$ctl00$OwnershipYAxisData" type="hidden" value="0.4,43.8,26.6,29.2"/>
# <input id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_HiddenSuburbName" name="ctl00$uxContentHolder$dzMainMid$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$ctl00$HiddenSuburbName" type="hidden" value="Applecross"/>
# <input id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_HiddenMedianHousePriceDisplay" name="ctl00$uxContentHolder$dzMainMid$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$ctl00$HiddenMedianHousePriceDisplay" type="hidden" value="True"/>
# <input id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_HiddenMedianUnitPriceDisplay" name="ctl00$uxContentHolder$dzMainMid$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$ctl00$HiddenMedianUnitPriceDisplay" type="hidden" value="True"/>
# <input id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_HiddenMedianLandPriceDisplay" name="ctl00$uxContentHolder$dzMainMid$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$ctl00$HiddenMedianLandPriceDisplay" type="hidden" value="True"/>
# <!-- Suburb facts -->
# <input id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_GrowthRatesVisibleForHouse" name="ctl00$uxContentHolder$dzMainMid$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$ctl00$GrowthRatesVisibleForHouse" type="hidden" value="1"/>
# <input id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_GrowthRatesVisibleForMultiRes" name="ctl00$uxContentHolder$dzMainMid$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$ctl00$GrowthRatesVisibleForMultiRes" type="hidden" value="1"/>
# <input id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_GrowthRatesVisibleForLand" name="ctl00$uxContentHolder$dzMainMid$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$ctl00$GrowthRatesVisibleForLand" type="hidden" value="1"/>
# <div class="clearfix">
# </div>
# <div id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_ContentPanel">
# <!-- Chart Tabs -->
# <a href='javascript:WebForm_DoPostBackWithOptions(new WebForm_PostBackOptions("ctl00$uxContentHolder$dzMainMid$uxColumnDisplay$ctl00$uxControlColumn$ctl00$uxWidgetHost$uxWidgetHost_widget$ctl00$TriggerChartPanel", "", true, "", "", false, true))' id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_TriggerChartPanel"></a>
# <div id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_TabContainer">
# <div class="vert-rhythm-xl">
# <div class="tabs-wrap nav-tabs-light reiwa-tabs hidden" id="ChartPanel">
# <div id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_divMedianGraphTabs">
# <div class="clearfix navtab-toolbar">
# <h2 class="navtab-heading pull-left">Applecross price charts</h2>
# <div class="clearfix visible-sm visible-xs vert-rhythm-md"></div>
# <ul class="nav nav-tabs pull-right nav-tabs-sm" id="Chart1">
# <li class="col-xs-4 remove-padding" id="MedianHouseTab"><a class="house-price suburb-profile-price-charts-tab" data-toggle="tab" href="#house-price" onclick="postgraph(1);">Median house price</a></li>
# <li class="col-xs-4 remove-padding" id="MedianUnitTab"><a class="multires-price suburb-profile-price-charts-tab" data-toggle="tab" href="#multires-price" onclick="postgraph(2);">Median unit price</a></li>
# <li class="col-xs-4 remove-padding" id="MedianLandTab"><a class="land-price suburb-profile-price-charts-tab" data-toggle="tab" href="#land-price" onclick="postgraph(3);">Median land price</a></li>
# </ul>
# </div>
# </div>
# <div class="tab-content clearfix tab-border">
# <div class="tab-pane fade in active" id="house-price">
# <div id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_divHousePrice">
# <div>
# <br/>
# ...
#                                     </a>
# </li>
# <li>
# <a href="/about-us/advertise-with-us/" title="Advertise with us">
# <span class="footer-icon fa fa-chevron-right"></span>Advertise with us
#                                     </a>
# </li>
# <li>
# <a href="/about-us/in-the-community/" title="In the community">
# <span class="footer-icon fa fa-chevron-right"></span>In the community
#                                     </a>
# </li>
# <li>
# <a href="/about-us/contact-us/" title="Contact us">
# <span class="footer-icon fa fa-chevron-right"></span>Contact us
#                                     </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-sm-6 col-md-7 hide-mobile">
# <div class="row">
# <div class="col-sm-12 col-md-6">
# <h3>Latest news</h3>
# <ul class="list-footer legalLinksFooter">
# <li>
# <a href="/About-Us/News/Perth-Market-Snapshot-for-the-week-ending-5-September-2021/">
# <div class="inline-block" style="vertical-align: top;"><span class="footer-icon fa fa-chevron-right"></span></div>
# <div class="inline-block" style="max-width: 75%;">Perth Market Snapshot for the week ending 5 September 2021</div>
# </a>
# </li>
# <li>
# <a href="/About-Us/News/Perth-Market-Snapshot-for-the-week-ending-29-August-2021/">
# <div class="inline-block" style="vertical-align: top;"><span class="footer-icon fa fa-chevron-right"></span></div>
# <div class="inline-block" style="max-width: 75%;">Perth Market Snapshot for the week ending 29 August 2021</div>
# </a>
# </li>
# <li>
# <a href="/About-Us/News/WA-real-estate-s-best-celebrated-at-2021-reiwa-com-Awards-Ball/">
# <div class="inline-block" style="vertical-align: top;"><span class="footer-icon fa fa-chevron-right"></span></div>
# <div class="inline-block" style="max-width: 75%;">WA real estate’s best celebrated at 2021 reiwa.com Awards Ball</div>
# </a>
# </li>
# </ul>
# <a class="footer-strong-link" href="/about-us/news/">View all</a>
# </div>
# <!-- Hidden in Tablet -->
# <div class="hidden-sm col-md-6">
# <div class="row">
# <div class="col-md-12 footer-newsletter-container" role="form">
# <h3>Subscribe for the latest WA news</h3>
# <div class="footer-newsletter-form vert-bottom-lg">
# <input class="footer-newsletter-tb inline-block" id="newsletter-subscription-email" name="newsletter-subscription-email" placeholder="Email address" type="text"/>
# <input class="newsletter-subscription-button btn btn-primary footer-newsletter-btn inline-block" id="btnNewsletterSubmit" type="button" value="Submit"/>
# </div>
# <div class="footer-newsletter-complete vert-bottom-lg" style="display: none;">
# <span>You have successfully subscribed</span>
# </div>
# </div>
# <div class="col-md-12 footer-newsletter-container">
# <div class="form-site-search" id="ctl00_Footer1_pnlSearch">
# <div class="searchExtendedBoxContainer footer-searchbar-container inline-block">
# <input class="footer-searchbar-tb search-site" id="ctl00_Footer1_txtSearchSite" name="ctl00$Footer1$txtSearchSite" placeholder="Search reiwa.com" type="text"/>
# <a href='javascript:WebForm_DoPostBackWithOptions(new WebForm_PostBackOptions("ctl00$Footer1$btnTopSearch", "", true, "", "", false, true))' id="ctl00_Footer1_btnTopSearch">
# <span class="fa fa-search footer-searchbar-icon"></span>
# </a>
# </div>
# <div class="extendedBox">
# <div class="innerBox">
# <span>Did you want to search for your term in:</span>
# <ul>
# <li>
# <input id="ctl00_Footer1_btnPropertySearch" name="ctl00$Footer1$btnPropertySearch" onclick='javascript:WebForm_DoPostBackWithOptions(new WebForm_PostBackOptions("ctl00$Footer1$btnPropertySearch", "", true, "", "", false, false))' type="submit" value="Properties for sale &gt; "/>
# </li>
# <li>
# <input id="ctl00_Footer1_btnSearchSuburb" name="ctl00$Footer1$btnSearchSuburb" onclick='javascript:WebForm_DoPostBackWithOptions(new WebForm_PostBackOptions("ctl00$Footer1$btnSearchSuburb", "", true, "", "", false, false))' type="submit" value="Suburbs &gt; "/>
# </li>
# <li>
# <input id="ctl00_Footer1_btnAgents" name="ctl00$Footer1$btnAgents" onclick='javascript:WebForm_DoPostBackWithOptions(new WebForm_PostBackOptions("ctl00$Footer1$btnAgents", "", true, "", "", false, false))' type="submit" value="AgentFinder &gt; "/>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="col-sm-6 col-md-12 footer-socialicons-container">
# <!-- AddThis social media buttons -->
# <div id="ctl00_Footer1_pnlAddThisDesktopIcons">
# <!-- Extend footer height to make room for share buttons on mobile -->
# <style>
#                                                 @media (max-width: 769px) {
#                                                     .legal-footer{
#                                                         min-height: 130px;
#                                                     }
#                                                 }
#                                             </style>
# <div class="addthis_inline_follow_toolbox"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- Mobile Footer -->
# <div class="col-sm-6 col-md-5 mobile-footer hide-desktop vert-bottom">
# <!-- Useful Pages -->
# <div class="container">
# <div class="row mobile-footer-toolbar">
# <div class="col-xs-12">
# <a class="js-show-mobile-footer mobile-footer-toggle"><span class="sr-only">Useful pages</span><span class="fa fa-chevron-down pull-right"></span>
# <h3>Useful pages</h3></a>
# </div>
# </div>
# <div class="row mobile-footer-content" style="display: none;">
# <ul class="list-footer legalLinksFooter">
# <li>
# <a href="/advice/calculator-tools/" title="Calculators">
# <span class="footer-icon fa fa-calculator"></span>Calculators
#                 </a>
# </li>
# <li>
# <a href="/videos/" title="Videos">
# <span class="footer-icon fa fa-play"></span>Videos
#                 </a>
# </li>
# <li>
# <a href="https://maps.reiwa.com.au" title="Interactive maps">
# <span class="footer-icon fa fa-map-marker"></span>Interactive maps
#                 </a>
# </li>
# <li>
# <a href="/sitemap/" title="Sitemap">
# <span class="footer-icon fa fa-sitemap"></span>Sitemap
#                 </a>
# </li>
# <li>
# <a href="/faqs/" title="FAQs">
# <span class="footer-icon fa fa-question-circle"></span>FAQs
#                 </a>
# </li>
# <li>
# <a href="/jobs-in-real-estate/" title="Jobs in real estate">
# <span class="footer-icon fa fa-users"></span>Jobs in real estate
#                 </a>
# </li>
# <li>
# <a href="/advice/information/" title="Advice">
# <span class="footer-icon fa fa-comment"></span>Advice
#                 </a>
# </li>
# </ul>
# </div>
# </div>
# <!-- About Us -->
# <div class="container">
# <div class="row mobile-footer-toolbar">
# <div class="col-xs-12">
# <a class="js-show-mobile-footer mobile-footer-toggle"><span class="sr-only">About us</span><span class="fa fa-chevron-down pull-right"></span>
# <h3>About us</h3></a>
# </div>
# </div>
# <div class="row mobile-footer-content" style="display: none;">
# <ul class="list-footer legalLinksFooter">
# <li>
# <a href="/about-us/about-reiwa/" title="About REIWA">
# <span class="footer-icon fa fa-chevron-right"></span>About REIWA
#                 </a>
# </li>
# <li>
# <a href="/about-us/reiwa-advocacy/" title="Advocacy">
# <span class="footer-icon fa fa-chevron-right"></span>Advocacy
#                 </a>
# </li>
# <li>
# <a href="/about-us/advertise-with-us/" title="Advertise with us">
# <span class="footer-icon fa fa-chevron-right"></span>Advertise with us
#                 </a>
# </li>
# <li>
# <a href="/about-us/in-the-community/" title="In the community">
# <span class="footer-icon fa fa-chevron-right"></span>In the community
#                 </a>
# </li>
# <li>
# <a href="/about-us/contact-us/" title="Contact us">
# <span class="footer-icon fa fa-chevron-right"></span>Contact us
#                 </a>
# </li>
# </ul>
# </div>
# </div>
# <!-- Latest news -->
# <div class="container">
# <div class="row mobile-footer-toolbar">
# <div class="col-md-3 col-md-offset-9 col-xs-12">
# <a class="js-show-mobile-footer mobile-footer-toggle"><span class="sr-only">Latest news</span><span class="fa fa-chevron-down pull-right"></span>
# <h3>Latest news</h3></a>
# </div>
# </div>
# <div class="row mobile-footer-content" style="display: none;">
# <ul class="list-footer legalLinksFooter">
# <li>
# <a href="/About-Us/News/Perth-Market-Snapshot-for-the-week-ending-5-September-2021/" title="Perth Market Snapshot for the week ending 5 September 2021">
# <div class="inline-block" style="vertical-align: top;">
# <span class="footer-icon fa fa-chevron-right"></span>
# </div>
# <div class="inline-block" style="max-width: 75%">Perth Market Snapshot for the week ending 5 September 2021</div>
# </a>
# </li>
# <li>
# <a href="/About-Us/News/Perth-Market-Snapshot-for-the-week-ending-29-August-2021/" title="Perth Market Snapshot for the week ending 29 August 2021">
# <div class="inline-block" style="vertical-align: top;">
# <span class="footer-icon fa fa-chevron-right"></span>
# </div>
# <div class="inline-block" style="max-width: 75%">Perth Market Snapshot for the week ending 29 August 2021</div>
# </a>
# </li>
# <li>
# <a href="/About-Us/News/WA-real-estate-s-best-celebrated-at-2021-reiwa-com-Awards-Ball/" title="WA real estate’s best celebrated at 2021 reiwa.com Awards Ball">
# <div class="inline-block" style="vertical-align: top;">
# <span class="footer-icon fa fa-chevron-right"></span>
# </div>
# <div class="inline-block" style="max-width: 75%">WA real estate’s best celebrated at 2021 reiwa.com Awards Ball</div>
# </a>
# </li>
# </ul>
# <a class="footer-strong-link" href="/about-us/news/">View all</a>
# </div>
# </div>
# </div>
# </div>
# <!-- tablet/mobile social media -->
# <div class="row hidden-md hidden-lg hidden-xl">
# <div class="col-sm-6 footer-newsletter-container-mobile" role="form">
# <h3>Subscribe for the latest WA news</h3>
# <div class="footer-newsletter-form vert-bottom-lg">
# <input class="footer-newsletter-tb inline-block" id="newsletter-subscription-email-tablet" name="newsletter-subscription-email" placeholder="Email address" type="text"/>
# <input class="newsletter-subscription-button btn btn-primary footer-newsletter-btn inline-block" id="btnNewsletterSubmitTablet" type="button" value="Submit"/>
# </div>
# <div class="footer-newsletter-complete vert-bottom-lg" style="display: none;">
# <span>You have successfully subscribed</span>
# </div>
# </div>
# <div class="col-xs-12 col-sm-6">
# <!-- AddThis social media buttons -->
# <div id="ctl00_Footer1_pnlAddThisMobileIcons">
# <div class="addthis_inline_follow_toolbox"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="app-links app-links-small">
# <span>Download the <strong>reiwa.com</strong> app</span>
# <div>
# <a href="https://itunes.apple.com/au/app/id1417769562" title="Download on the App Store">
# <img alt="Download on the App Store" height="40" src="/UX/reiwa/UX/images/app-store-badge.svg" style="width: inherit;" width="120"/></a>
# <a href="https://play.google.com/store/apps/details?id=com.reiwa.app" title="Download on Google Play">
# <img alt="Download on Google Play" height="40" src="/UX/reiwa/UX/images/google-play-badge.png" style="width: inherit;" width="134"/></a>
# </div>
# </div>
# <div class="row footer-disclaimer-text horz-rhythm-lg">
# <p class="disclaimer"><em>REIWA acknowledges the Traditional Owners of this land, the Whadjuk Nyoongar people, and pays respect to Elders, past, present and emerging.</em> </p><p class="disclaimer">REIWA disclaims liability for the accuracy of information on reiwa.com. REIWA collects information from reiwa.com and other sources. REIWA at all times retains copyright and holds all intellectual property rights to reiwa.com and its data. Full details are set out in the Disclaimer/Copyright and Privacy Statement links below.  <br/>For REIWA forms for non-members and RTOs, call us on 9380 8222.</p>
# </div>
# </div>
# </div>
# <!-- /Global Footer -->
# <!-- Logo and legal links -->
# <div class="legal-footer">
# <div class="container">
# <div class="row">
# <div class="col-xs-12 col-sm-5">
# <div class="row">
# <a class="footer-logo hide-mobile" href="/About-Us/About-REIWA/"><span class="sr-only">REIWA.com</span></a>
# </div>
# <div class="row footerVersionNumber">
# <a data-alert="modal" href="#" style="font-size: 7pt; color: #fff;">Version 3.21.0 served by AUEASTGRWEB002</a>
# </div>
# </div>
# <div class="col-xs-12 col-sm-7 vert-rhythm-md">
# <div class="legalLinksFooter">
# <ul class="list-inline pull-right-desktop" id="ctl00_Footer1_uxLegalLinks_uxUlWrapper">
# <li>
# <a href="http://reia.asn.au/the-institute/members/" target="_blank" title="http://reia.asn.au/the-institute/members/">
#                         National Network
#                     </a>
# </li>
# <li>
# <a href="/Disclaimer/" target="" title="/Disclaimer/">
#                         Disclaimer/Copyright
#                     </a>
# </li>
# <li>
# <a href="/Privacy-Statement/" target="" title="/Privacy-Statement/">
#                         Privacy Statement
#                     </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- /Logo and legal links -->
# <!-- AddThis social media buttons -->
# <div id="ctl00_Footer1_pnlAddThisScript">
# <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5d688921df265b55" type="text/javascript"></script>
# </div>
# </footer>
# <!-- /Footer Control (Footer) -->
# </div><!--END page-container-->
# </div><!-- End OFF Canvas -->
# <!--/sse-->
# <!-- Hotjar Tracking Code for reiwa.com.au -->
# <script async="" type="text/javascript">
#         (function (h, o, t, j, a, r) {
#             h.hj = h.hj || function () { (h.hj.q = h.hj.q || []).push(arguments) }
#                 ;
#             h._hjSettings = { hjid: 2151212, hjsv: 6 };
#             a = o.getElementsByTagName('head')[0];
#             r = o.createElement('script'); r.async = 1;
#             r.src = t + h._hjSettings.hjid + j + h._hjSettings.hjsv;
#             a.appendChild(r);
#         })(window, document, 'https://static.hotjar.com/c/hotjar-', '.js?sv=');
#     </script>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-P69FT3" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script async="" type="text/javascript">(function (w, d, s, l, i) {
#             w[l] = w[l] || []; w[l].push({
#                 'gtm.start':
#                     new Date().getTime(), event: 'gtm.js'
#             }); var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                 '//www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-P69FT3');
#     </script>
# <!-- End Google Tag Manager -->
# <!-- Pardot tracking -->
# <script async="" type="text/javascript">
#             piAId = '485941';
#             piCId = '6290';
#             piHostname = 'pi.pardot.com';
#             (function() {
#                 function async_load() {
#                     var s = document.createElement('script');
#                     s.type = 'text/javascript';
#                     s.src =
#                         ('https:' == document.location.protocol ? 'https://pi' : 'http://cdn') + '.pardot.com/pd.js';
#                     var c = document.getElementsByTagName('script')[0];
#                     c.parentNode.insertBefore(s, c);
#
#                 }
#
#                 if (window.attachEvent) {
#                     window.attachEvent('onload', async_load);
#                 } else {
#                     window.addEventListener('load', async_load, false);
#                 }
#             })();
#         </script>
# <!-- end Pardot tracking -->
# <!-- Script Placeholder configured in code behind-->
# <script src="/WorkArea/FrameworkUI/js/ektron.javascript.ashx?ver=3.21.0&amp;id=1860464903+-1163639748+620270482+-1250874870+1699482349+-1251490955+67436383+-993784877+1349732761+757130540+1600218572+-1153875193+1914965633+1853295748+902309670+-919434566+-1293123525+-127140165+-847686342+2140596708+1581766698+695237143+-1574337509+969804857+-1152689727+-1085004766+-1716608124+998994086+-2076844529+1792486806+177711107+-535651174+509557905" type="text/javascript"></script>
# </form>
# <!-- Live Chat -->
# <script data-cf-beacon='{"rayId":"68a78002fac65a7f","token":"ca9e866a516f43b2aa32bc0697964042","version":"2021.8.1","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js"></script>
# </body>
# </html>

# %%
# Examine the results, then determine element that contains sought info
results = soup.find_all('td', class_='text-left col-xs-8')[4]('span')
print(results)
# Out:
# [<span id="ctl00_uxContentHolder_dzMainMid_uxColumnDisplay_ctl00_uxControlColumn_ctl00_uxWidgetHost_uxWidgetHost_widget_ctl00_StatsOtherNearbySchools"> Applecross Senior High School, Aquinas College, Santa Maria College, Como Secondary College, Melville Senior High School, Corpus Christi College, Penrhos College, Rossmoyne Senior High School, All Saints' College, Wesley College</span>]

# %%
# pick out only the data elements
data_schools = [element.text for element in results][0]
print(data_schools)
# Out:
#  Applecross Senior High School, Aquinas College, Santa Maria College, Como Secondary College, Melville Senior High School, Corpus Christi College, Penrhos College, Rossmoyne Senior High School, All Saints' College, Wesley College

# %%
split_data=data_schools.split(',')
print(split_data)
# Out:
# [' Applecross Senior High School', ' Aquinas College', ' Santa Maria College', ' Como Secondary College', ' Melville Senior High School', ' Corpus Christi College', ' Penrhos College', ' Rossmoyne Senior High School', " All Saints' College", ' Wesley College']

# %%
# Add the list of schools to a dataframe for filtering
# rename column
applecross_df = pd.DataFrame(split_data).rename(columns = {0:'School_Name'})

# make it upper case for consistency with other datasets
applecross_df['School_Name']=applecross_df['School_Name'].str.upper()

applecross_df.head()
# Out:
#                       School_Name
# 0   APPLECROSS SENIOR HIGH SCHOOL
# 1                 AQUINAS COLLEGE
# 2             SANTA MARIA COLLEGE
# 3          COMO SECONDARY COLLEGE
# 4     MELVILLE SENIOR HIGH SCHOOL

# %%
applecross_df['School_Name']=applecross_df['School_Name'].str.strip()
new_WASchools_df["School_Name"]= new_WASchools_df.School_Name.str.strip()

# %%
# merge in school_id
applecross_df2= pd.merge(applecross_df, new_WASchools_df, on="School_Name", how = "left").drop(["Classification_Group","Y12","School_Name"],axis=1)
applecross_df2.head()
# Out:
#    School_ID
# 0          6
# 1          7
# 2        244
# 3         63
# 4        188

# %% [markdown]
# # Datasource 3

# %%
# <!-- URL for Data source 3 – WA School Ranking – 2020 -->
url = 'https://bettereducation.com.au/results/wa/wace.aspx'

# <!-- read table -->
tables = pd.read_html(url)
tables
# Out:
# [     Unnamed: 0  Better Education Rank                                School  \
#  0             1                      1                   Perth Modern School
#  1             2                      2  St Hilda's Anglican School for Girls
#  2             3                      3          Christ Church Grammar School
#  3             4                      4                       Penrhos College
#  4             5                      5             Methodist Ladies' College
#  ..          ...                    ...                                   ...
#  134         135                    135           Balcatta Senior High School
#  135         136                    136         Safety Bay Senior High School
#  136         137                    137          Darling Range Sports College
#  137         138                    138                       Gilmore College
#  138         139                    139                 Cecil Andrews College
#
#       Median ATAR  No. eligible Yr 12 students  No. Students with an ATAR  \
#  0          97.55                          242                        242
#  1          92.70                          147                        134
#  2          92.50                          190                        175
#  3          90.65                          135                        116
#  4          90.55                          126                        112
#  ..           ...                          ...                        ...
#  134        60.40                           76                         20
#  135        58.75                          115                         23
#  136        52.40                          129                         44
#  137        52.25                          141                         23
#  138        49.85                           77                         20
#
#       % students with an ATAR  Trend / Compare
#  0                     100.00  Trend / Compare
#  1                      91.16  Trend / Compare
#  2                      92.11  Trend / Compare
#  3                      85.93  Trend / Compare
#  4                      88.89  Trend / Compare
#  ..                       ...              ...
#  134                    26.32  Trend / Compare
#  135                    20.00  Trend / Compare
#  136                    34.11  Trend / Compare
#  137                    16.31  Trend / Compare
#  138                    25.97  Trend / Compare
#
#  [139 rows x 8 columns]]

# %%
# check table type
type(tables)
# Out:
# list

# %%
# insert table into a df and drop the first column
df = tables[0].drop(['Unnamed: 0'], axis=1)
df.head()
# Out:
#    Better Education Rank                                School  Median ATAR  \
# 0                      1                   Perth Modern School        97.55
# 1                      2  St Hilda's Anglican School for Girls        92.70
# 2                      3          Christ Church Grammar School        92.50
# 3                      4                       Penrhos College        90.65
# 4                      5             Methodist Ladies' College        90.55
#
#    No. eligible Yr 12 students  No. Students with an ATAR  \
# 0                          242                        242
# 1                          147                        134
# 2                          190                        175
# 3                          135                        116
# 4                          126                        112
#
#    % students with an ATAR  Trend / Compare
# 0                   100.00  Trend / Compare
# 1                    91.16  Trend / Compare
# 2                    92.11  Trend / Compare
# 3                    85.93  Trend / Compare
# 4                    88.89  Trend / Compare

# %%
# only keep data that is useful for end user
df = df[['Better Education Rank','School','Median ATAR']]
df.head()
# Out:
#    Better Education Rank                                School  Median ATAR
# 0                      1                   Perth Modern School        97.55
# 1                      2  St Hilda's Anglican School for Girls        92.70
# 2                      3          Christ Church Grammar School        92.50
# 3                      4                       Penrhos College        90.65
# 4                      5             Methodist Ladies' College        90.55

# %%
cols = list(df.columns)
# rename columns to something more descriptive 
cols[0] = "2020_ATAR_Secondary_School_Ranking"
# rename School to School Name to tie in with Data Source 2
cols[1] = "School_Name"
cols[2] = "Median_ATAR"
df.columns = cols

# make the school name uppercase to enable easier merge for end user
df['School_Name'] = df['School_Name'].str.upper()

df.head()
# Out:
#    2020_ATAR_Secondary_School_Ranking                           School_Name  \
# 0                                   1                   PERTH MODERN SCHOOL
# 1                                   2  ST HILDA'S ANGLICAN SCHOOL FOR GIRLS
# 2                                   3          CHRIST CHURCH GRAMMAR SCHOOL
# 3                                   4                       PENRHOS COLLEGE
# 4                                   5             METHODIST LADIES' COLLEGE
#
#    Median_ATAR
# 0        97.55
# 1        92.70
# 2        92.50
# 3        90.65
# 4        90.55

# %%
# merge in school_id
secondary_schools_df = pd.merge(df, new_WASchools_df, on="School_Name", how = "left").drop(["Classification_Group","Y12"],axis=1)
secondary_schools_df.head()
# Out:
#    2020_ATAR_Secondary_School_Ranking                           School_Name  \
# 0                                   1                   PERTH MODERN SCHOOL
# 1                                   2  ST HILDA'S ANGLICAN SCHOOL FOR GIRLS
# 2                                   3          CHRIST CHURCH GRAMMAR SCHOOL
# 3                                   4                       PENRHOS COLLEGE
# 4                                   5             METHODIST LADIES' COLLEGE
#
#    Median_ATAR  School_ID
# 0        97.55      224.0
# 1        92.70      266.0
# 2        92.50       52.0
# 3        90.65      221.0
# 4        90.55      192.0

# %%
# check if there's any bad data that didn't merge
secondary_schools_df[secondary_schools_df['School_ID'].isnull()]
# Out:
#      2020_ATAR_Secondary_School_Ranking  \
# 10                                   11
# 48                                   49
# 61                                   62
# 101                                 102
#
#                                       School_Name  Median_ATAR  School_ID
# 10                   PRESBYTERIAN LADIES' COLLEGE        89.20        NaN
# 48   CHRISTIAN BROTHERS COLLEGE,FREMANTLE,WA,6160        82.20        NaN
# 61       CAREY BAPTIST COLLEGE,HARRISDALE,WA,6112        80.30        NaN
# 101          AUSTRALIAN ISLAMIC COLLEGE (KEWDALE)        72.55        NaN

# %%
# replace bad data
secondary_schools_df['School_Name'] = df['School_Name'].replace(
    {"PRESBYTERIAN LADIES' COLLEGE":"PRESBYTERIAN LADIES COLLEGE","CHRISTIAN BROTHERS COLLEGE,FREMANTLE,WA,6160":"CHRISTIAN BROTHERS' COLLEGE","CAREY BAPTIST COLLEGE,HARRISDALE,WA,6112":"CAREY BAPTIST COLLEGE","AUSTRALIAN ISLAMIC COLLEGE (KEWDALE)":"AUSTRALIAN ISLAMIC COLLEGE - KEWDALE"})

secondary_schools_df[secondary_schools_df['School_ID'].isnull()]
# Out:
#      2020_ATAR_Secondary_School_Ranking                           School_Name  \
# 10                                   11           PRESBYTERIAN LADIES COLLEGE
# 48                                   49           CHRISTIAN BROTHERS' COLLEGE
# 61                                   62                 CAREY BAPTIST COLLEGE
# 101                                 102  AUSTRALIAN ISLAMIC COLLEGE - KEWDALE
#
#      Median_ATAR  School_ID
# 10         89.20        NaN
# 48         82.20        NaN
# 61         80.30        NaN
# 101        72.55        NaN

# %%
secondary_schools_df.head()
# Out:
#    2020_ATAR_Secondary_School_Ranking                           School_Name  \
# 0                                   1                   PERTH MODERN SCHOOL
# 1                                   2  ST HILDA'S ANGLICAN SCHOOL FOR GIRLS
# 2                                   3          CHRIST CHURCH GRAMMAR SCHOOL
# 3                                   4                       PENRHOS COLLEGE
# 4                                   5             METHODIST LADIES' COLLEGE
#
#    Median_ATAR  School_ID
# 0        97.55      224.0
# 1        92.70      266.0
# 2        92.50       52.0
# 3        90.65      221.0
# 4        90.55      192.0

# %%
# drop School_ID for later remerge for clean data
secondary_schools_df=secondary_schools_df.drop(["School_ID"],axis=1)
secondary_schools_df.head()
# Out:
#    2020_ATAR_Secondary_School_Ranking                           School_Name  \
# 0                                   1                   PERTH MODERN SCHOOL
# 1                                   2  ST HILDA'S ANGLICAN SCHOOL FOR GIRLS
# 2                                   3          CHRIST CHURCH GRAMMAR SCHOOL
# 3                                   4                       PENRHOS COLLEGE
# 4                                   5             METHODIST LADIES' COLLEGE
#
#    Median_ATAR
# 0        97.55
# 1        92.70
# 2        92.50
# 3        90.65
# 4        90.55

# %%
# merge in school_id
secondary_schools_df2 = pd.merge(new_WASchools_df,secondary_schools_df, on="School_Name", how = "right").drop(["Classification_Group","School_Name","Y12"],axis=1)
secondary_schools_df2.head()
# Out:
#    School_ID  2020_ATAR_Secondary_School_Ranking  Median_ATAR
# 0        224                                   1        97.55
# 1        266                                   2        92.70
# 2         52                                   3        92.50
# 3        221                                   4        90.65
# 4        192                                   5        90.55

# %%
# check if there's any bad data that didn't merge
secondary_schools_df2[secondary_schools_df2['School_ID'].isnull()]
# Out:
# Empty DataFrame
# Columns: [School_ID, 2020_ATAR_Secondary_School_Ranking, Median_ATAR]
# Index: []

# %% [markdown]
# # LOAD

# %%
rds_connection_string = f"{username}:{password}@localhost:5432/schools_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# check for tables - NOTE this is created in pgadmin before hand
engine.table_names()
# Out:
# <ipython-input-70-2caba68b8947>:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# []

# %%
# note - delete all tables in pg admin schools_db before running the next step

# %%
# NOTE - DON'T RUN MORE THAN ONCE BECUASE IT APPENDS

# Dataset 1
new_WASchools_df2.to_sql(name='wa_schools_y12', con=engine, if_exists='append', index=False)

# Dataset 2
classification_df.to_sql(name='wa_schools_classification', con=engine, if_exists='append', index=False)

# Dataset 3
applecross_df2.to_sql(name='applecross_secondary_schools', con=engine, if_exists='append', index=False)

# Dataset 4
secondary_schools_df2.to_sql(name='secondary_schools_ranking', con=engine, if_exists='append', index=False)

# %%
# confirm Dataset 1 has been added
pd.read_sql_query('select * from wa_schools_y12', con=engine).head()
# Out:
#    School_ID                                School_Name    Y12  \
# 0          0                           AL-AMEEN COLLEGE   45.0
# 1          1  ALBANY SECONDARY EDUCATION SUPPORT CENTRE   17.0
# 2          2                  ALBANY SENIOR HIGH SCHOOL  130.0
# 3          3                    ALKIMOS BAPTIST COLLEGE   12.0
# 4          4                        ALL SAINTS' COLLEGE  144.0
#
#    Classification_ID
# 0                  0
# 1                  1
# 2                  2
# 3                  0
# 4                  0

# %%
# confirm Dataset 2 has been added
pd.read_sql_query('select * from wa_schools_classification', con=engine).head()
# Out:
#    Classification_ID   Classification_Group
# 0                  0         NON-GOVERNMENT
# 1                  1      EDUCATION SUPPORT
# 2                  2      SECONDARY SCHOOLS
# 3                  3           K-12 SCHOOLS
# 4                  4  DISTRICT HIGH SCHOOLS

# %%
# confirm Dataset 3 has been added
pd.read_sql_query('select * from applecross_secondary_schools', con=engine).head()
# Out:
#    School_ID
# 0          6
# 1          7
# 2        244
# 3         63
# 4        188

# %%
# confirm Dataset 4 has been added
pd.read_sql_query('select * from secondary_schools_ranking', con=engine).head()
# Out:
#    School_ID  2020_ATAR_Secondary_School_Ranking  Median_ATAR
# 0        224                                   1        97.55
# 1        266                                   2        92.70
# 2         52                                   3        92.50
# 3        221                                   4        90.65
# 4        192                                   5        90.55
